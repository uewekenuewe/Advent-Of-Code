# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
import random
from collections import Counter

# %%
# Out:
# 0.24696150597143363

# %%
# Using readlines()
file1 = open('input.txt', 'r')
#file1 = open('input.txt', 'r')
Lines = file1.readlines()
Lines
numbers = re.findall('\d+',Lines[0])
numbers = [int(x) for x in numbers]
#print(numbers)
avg_numbers = round(sum(numbers)/len(numbers))
results = []
for i in numbers:
    sum_numbers = 0
    for k in numbers: 
        sum_numbers += abs(i-k)
        #print(i,k,abs(i-k))
    results.append(sum_numbers)
print('result1:',min(results))
print('-----')

print('avg',avg_numbers)
results_2 = []
#for y in range(0,max(numbers)):
#for y in range(avg_numbers-300,avg_numbers+300):
#    results_1 = []
#    for i in numbers:
#        result = 0
#        for k in range(1,abs(i-y)+1):
#            result += k
#        #print(y,i,result)    
#        results_1.append(result)
#    results_2.append(sum(results_1))
#
#print('result2:',min(results_2))
#print('result2:',min(results))
# end result: 98231647
# Out:
# result1: 348996
# -----
# avg 482

# %%
print('avg',avg_numbers)
results_2 = []
x = numbers 
y = [random.uniform(0, 1) for i in numbers]
#print(y,x)    
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# avg 482

# %%
print(sum(numbers[:534]))
print(sum(numbers[534:]))
print(len(numbers))

df = pd.DataFrame(data=numbers)
df.hist()
# Out:
# 241796
# 239724
# 1000
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
print(sum(numbers))
x = 0
for i in range(0,len(numbers)):
    if x >= sum(numbers)/2:
        print(x,i,numbers[i])
        break
    x += numbers[i]
# Out:
# 481520
# 241796 534 1428

# %%
sum(numbers)
# Out:
# 49

# %%
sum(numbers)/len(numbers)
# Out:
# 4.9

# %%
round(sum(numbers)/len(numbers))
# Out:
# 5
